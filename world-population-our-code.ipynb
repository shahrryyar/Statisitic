# %% [markdown]
# # Important Jupyter shortcut
# tab to give function methods
# shift&tab parameter and help
# command&/ to comment ⌘/: comment

# %% [markdown]
# # Cardio Good Fitness Case Study - Descriptive Statistics
# The market research team at AdRight is assigned the task to identify the profile of the typical customer for each treadmill product offered by CardioGood Fitness. The market research team decides to investigate whether there are differences across the product lines with respect to customer characteristics. The team decides to collect data on individuals who purchased a treadmill at a CardioGoodFitness retail store during the prior three months. The data are stored in the CardioGoodFitness.csv file.
#
# ### The team identifies the following customer variables to study:
#   - product purchased, TM195, TM498, or TM798;
#   - gender;
#   - age, in years;
#   - education, in years;
#   - relationship status, single or partnered;
#   - annual household income ;
#   - average number of times the customer plans to use the treadmill each week;
#   - average number of miles the customer expects to walk/run each week;
#   - and self-rated fitness on an 1-to-5 scale, where 1 is poor shape and 5 is excellent shape.
#
# ### Perform descriptive analytics to create a customer profile for each CardioGood Fitness treadmill product line.

# %%
# # Load the necessary packages
import pandas as pd
import numpy as np

# %%
mydata = pd.read_csv('/content/world_population.csv')

# %%
mydata.tail(5)
# Out:
#      Rank CCA3  Country/Territory   Capital Continent  2022 Population  \
# 229   226  WLF  Wallis and Futuna  Mata-Utu   Oceania            11572
# 230   172  ESH     Western Sahara  El Aaiún    Africa           575986
# 231    46  YEM              Yemen     Sanaa      Asia         33696614
# 232    63  ZMB             Zambia    Lusaka    Africa         20017675
# 233    74  ZWE           Zimbabwe    Harare    Africa         16320537
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 229            11655            12182            13142            14723
# 230           556048           491824           413296           270375
# 231         32284046         28516545         24743946         18628700
# 232         18927715         16248230         13792086          9891136
# 233         15669666         14154937         12839771         11834676
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 229            13454            11315             9377         142
# 230           178529           116775            76371      266000
# 231         13375121          9204938          6843607      527968
# 232          7686401          5720438          4281671      752612
# 233         10113893          7049926          5202918      390757
#
#      Density (per km²)  Growth Rate  World Population Percentage
# 229            81.4930       0.9953                         0.00
# 230             2.1654       1.0184                         0.01
# 231            63.8232       1.0217                         0.42
# 232            26.5976       1.0280                         0.25
# 233            41.7665       1.0204                         0.20

# %%
# Load the Cardio Dataset
mydata = pd.read_csv('world_population.csv')

# %%
# mydata.head()
# mydata.columns
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
#  13  Area (km²)                   234 non-null    int64
#  14  Density (per km²)            234 non-null    float64
#  15  Growth Rate                  234 non-null    float64
#  16  World Population Percentage  234 non-null    float64
# dtypes: float64(3), int64(10), object(4)
# memory usage: 31.2+ KB

# %%
mydata.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# min       5.960000e+02     6.510000e+02     7.000000e+02     7.330000e+02
# 25%       3.931490e+05     3.272420e+05     2.641158e+05     2.296142e+05
# 50%       4.942770e+06     4.292907e+06     3.825410e+06     3.141146e+06
# 75%       1.915957e+07     1.576230e+07     1.186923e+07     9.826054e+06
# max       1.348191e+09     1.264099e+09     1.153704e+09     9.823725e+08
#
#        1970 Population    Area (km²)  Density (per km²)  Growth Rate  \
# count     2.340000e+02  2.340000e+02         234.000000   234.000000
# mean      1.578691e+07  5.814494e+05         452.127044     1.009577
# std       6.779509e+07  1.761841e+06        2066.121904     0.013385
# min       7.520000e+02  1.000000e+00           0.026100     0.912000
# 25%       1.559970e+05  2.650000e+03          38.417875     1.001775
# 50%       2.604830e+06  8.119950e+04          95.346750     1.007900
# 75%       8.817329e+06  4.304258e+05         238.933250     1.016950
# max       8.225344e+08  1.709824e+07       23172.266700     1.069100
#
#        World Population Percentage
# count                   234.000000
# mean                      0.427051
# std                       1.714977
# min                       0.000000
# 25%                       0.010000
# 50%                       0.070000
# 75%                       0.280000
# max                      17.880000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(30,40))
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="Growth Rate", y="Area (km²)", data=mydata)
# Out:
# <Axes: xlabel='Growth Rate', ylabel='Area (km²)'>

# %%
pd.crosstab(mydata['Growth Rate'],mydata['Area (km²)'] )
# Out:
# Area (km²)   1         2         6         12        21        26        \
# Growth Rate
# 0.9120              0         0         0         0         0         0
# 0.9816              0         0         0         0         0         0
# 0.9831              0         0         0         0         0         0
# 0.9849              0         0         0         0         0         0
# 0.9869              0         0         0         0         0         0
# ...               ...       ...       ...       ...       ...       ...
# 1.0359              0         0         0         0         0         0
# 1.0376              0         0         0         0         0         0
# 1.0378              0         0         0         0         0         0
# 1.0404              0         0         0         0         0         0
# 1.0691              0         0         0         0         0         0
#
# Area (km²)   30        34        53        54        ...  2381741   2724900   \
# Growth Rate                                          ...
# 0.9120              0         0         0         0  ...         0         0
# 0.9816              0         0         0         0  ...         0         0
# 0.9831              0         0         0         0  ...         0         0
# 0.9849              0         0         0         0  ...         0         0
# 0.9869              0         0         0         0  ...         0         0
# ...               ...       ...       ...       ...  ...       ...       ...
# 1.0359              0         0         0         0  ...         0         0
# 1.0376              0         0         0         0  ...         0         0
# 1.0378              0         0         0         0  ...         0         0
# 1.0404              0         0         0         0  ...         0         0
# 1.0691              0         0         0         0  ...         0         0
#
# Area (km²)   2780400   3287590   7692024   8515767   9372610   9706961   \
# Growth Rate
# 0.9120              0         0         0         0         0         0
# 0.9816              0         0         0         0         0         0
# 0.9831              0         0         0         0         0         0
# 0.9849              0         0         0         0         0         0
# 0.9869              0         0         0         0         0         0
# ...               ...       ...       ...       ...       ...       ...
# 1.0359              0         0         0         0         0         0
# 1.0376              0         0         0         0         0         0
# 1.0378              0         0         0         0         0         0
# 1.0404              0         0         0         0         0         0
# 1.0691              0         0         0         0         0         0
#
# Area (km²)   9984670   17098242
# Growth Rate
# 0.9120              0         0
# 0.9816              0         0
# 0.9831              0         0
# 0.9849              0         0
# 0.9869              0         0
# ...               ...       ...
# 1.0359              0         0
# 1.0376              0         0
# 1.0378              0         0
# 1.0404              0         0
# 1.0691              0         0
#
# [180 rows x 233 columns]

# %%
pd.crosstab(mydata['Growth Rate'],mydata['Area (km²)'] )
# Out:
# Area (km²)   1         2         6         12        21        26        \
# Growth Rate
# 0.9120              0         0         0         0         0         0
# 0.9816              0         0         0         0         0         0
# 0.9831              0         0         0         0         0         0
# 0.9849              0         0         0         0         0         0
# 0.9869              0         0         0         0         0         0
# ...               ...       ...       ...       ...       ...       ...
# 1.0359              0         0         0         0         0         0
# 1.0376              0         0         0         0         0         0
# 1.0378              0         0         0         0         0         0
# 1.0404              0         0         0         0         0         0
# 1.0691              0         0         0         0         0         0
#
# Area (km²)   30        34        53        54        ...  2381741   2724900   \
# Growth Rate                                          ...
# 0.9120              0         0         0         0  ...         0         0
# 0.9816              0         0         0         0  ...         0         0
# 0.9831              0         0         0         0  ...         0         0
# 0.9849              0         0         0         0  ...         0         0
# 0.9869              0         0         0         0  ...         0         0
# ...               ...       ...       ...       ...  ...       ...       ...
# 1.0359              0         0         0         0  ...         0         0
# 1.0376              0         0         0         0  ...         0         0
# 1.0378              0         0         0         0  ...         0         0
# 1.0404              0         0         0         0  ...         0         0
# 1.0691              0         0         0         0  ...         0         0
#
# Area (km²)   2780400   3287590   7692024   8515767   9372610   9706961   \
# Growth Rate
# 0.9120              0         0         0         0         0         0
# 0.9816              0         0         0         0         0         0
# 0.9831              0         0         0         0         0         0
# 0.9849              0         0         0         0         0         0
# 0.9869              0         0         0         0         0         0
# ...               ...       ...       ...       ...       ...       ...
# 1.0359              0         0         0         0         0         0
# 1.0376              0         0         0         0         0         0
# 1.0378              0         0         0         0         0         0
# 1.0404              0         0         0         0         0         0
# 1.0691              0         0         0         0         0         0
#
# Area (km²)   9984670   17098242
# Growth Rate
# 0.9120              0         0
# 0.9816              0         0
# 0.9831              0         0
# 0.9849              0         0
# 0.9869              0         0
# ...               ...       ...
# 1.0359              0         0
# 1.0376              0         0
# 1.0378              0         0
# 1.0404              0         0
# 1.0691              0         0
#
# [180 rows x 233 columns]

# %%
sns.countplot(x="Growth Rate", hue="Area (km²)", data=mydata)
# Out:
# <Axes: xlabel='Growth Rate', ylabel='count'>

# %%
pd.pivot_table(mydata, index=['Area (km²)', 'Growth Rate'],
                     columns=[ 'Area (km²)'], aggfunc=len)
# Out:
#                        1970 Population                                      \
# Area (km²)                    1        2        6        12       21
# Area (km²) Growth Rate
# 1          0.9980                  1.0      NaN      NaN      NaN      NaN
# 2          0.9941                  NaN      1.0      NaN      NaN      NaN
# 6          0.9994                  NaN      NaN      1.0      NaN      NaN
# 12         1.0119                  NaN      NaN      NaN      1.0      NaN
# 21         1.0098                  NaN      NaN      NaN      NaN      1.0
# ...                                ...      ...      ...      ...      ...
# 8515767    1.0046                  NaN      NaN      NaN      NaN      NaN
# 9372610    1.0038                  NaN      NaN      NaN      NaN      NaN
# 9706961    1.0000                  NaN      NaN      NaN      NaN      NaN
# 9984670    1.0078                  NaN      NaN      NaN      NaN      NaN
# 17098242   0.9973                  NaN      NaN      NaN      NaN      NaN
#
#                                                                      ...  \
# Area (km²)             26       30       34       53       54        ...
# Area (km²) Growth Rate                                               ...
# 1          0.9980           NaN      NaN      NaN      NaN      NaN  ...
# 2          0.9941           NaN      NaN      NaN      NaN      NaN  ...
# 6          0.9994           NaN      NaN      NaN      NaN      NaN  ...
# 12         1.0119           NaN      NaN      NaN      NaN      NaN  ...
# 21         1.0098           NaN      NaN      NaN      NaN      NaN  ...
# ...                         ...      ...      ...      ...      ...  ...
# 8515767    1.0046           NaN      NaN      NaN      NaN      NaN  ...
# 9372610    1.0038           NaN      NaN      NaN      NaN      NaN  ...
# 9706961    1.0000           NaN      NaN      NaN      NaN      NaN  ...
# 9984670    1.0078           NaN      NaN      NaN      NaN      NaN  ...
# 17098242   0.9973           NaN      NaN      NaN      NaN      NaN  ...
#
#                        World Population Percentage                             \
# Area (km²)                                2381741  2724900  2780400  3287590
# Area (km²) Growth Rate
# 1          0.9980                              NaN      NaN      NaN      NaN
# 2          0.9941                              NaN      NaN      NaN      NaN
# 6          0.9994                              NaN      NaN      NaN      NaN
# 12         1.0119                              NaN      NaN      NaN      NaN
# 21         1.0098                              NaN      NaN      NaN      NaN
# ...                                            ...      ...      ...      ...
# 8515767    1.0046                              NaN      NaN      NaN      NaN
# 9372610    1.0038                              NaN      NaN      NaN      NaN
# 9706961    1.0000                              NaN      NaN      NaN      NaN
# 9984670    1.0078                              NaN      NaN      NaN      NaN
# 17098242   0.9973                              NaN      NaN      NaN      NaN
#
#
# Area (km²)             7692024  8515767  9372610  9706961  9984670  17098242
# Area (km²) Growth Rate
# 1          0.9980           NaN      NaN      NaN      NaN      NaN      NaN
# 2          0.9941           NaN      NaN      NaN      NaN      NaN      NaN
# 6          0.9994           NaN      NaN      NaN      NaN      NaN      NaN
# 12         1.0119           NaN      NaN      NaN      NaN      NaN      NaN
# 21         1.0098           NaN      NaN      NaN      NaN      NaN      NaN
# ...                         ...      ...      ...      ...      ...      ...
# 8515767    1.0046           NaN      1.0      NaN      NaN      NaN      NaN
# 9372610    1.0038           NaN      NaN      1.0      NaN      NaN      NaN
# 9706961    1.0000           NaN      NaN      NaN      1.0      NaN      NaN
# 9984670    1.0078           NaN      NaN      NaN      NaN      1.0      NaN
# 17098242   0.9973           NaN      NaN      NaN      NaN      NaN      1.0
#
# [234 rows x 3495 columns]

# %%
pd.pivot_table(mydata,'Income', index=['Product', 'Gender'],
                     columns=[ 'MaritalStatus'])
# Out:
# MaritalStatus      Partnered        Single
# Product Gender
# TM195   Female  46153.777778  45742.384615
#         Male    50028.000000  43265.842105
# TM498   Female  49724.800000  48920.357143
#         Male    49378.285714  47071.800000
# TM798   Female  84972.250000  58516.000000
#         Male    81431.368421  68216.428571

# %%
mydata['Area (km²)'].std()
# Out:
# 1761840.8640631407

# %%
mydata['Area (km²)'].mean()
# Out:
# np.float64(581449.3846153846)

# %%
sns.displot(mydata['Area (km²)'])

# %%
mydata.hist(by='Growth Rate',column = 'Area (km²)')
# Out:
# array([[<Axes: title={'center': '0.912'}>,
#         <Axes: title={'center': '0.9816'}>,
#         <Axes: title={'center': '0.9831'}>,
#         <Axes: title={'center': '0.9849'}>,
#         <Axes: title={'center': '0.9869'}>,
#         <Axes: title={'center': '0.9876'}>,
#         <Axes: title={'center': '0.9886'}>,
#         <Axes: title={'center': '0.9897'}>,
#         <Axes: title={'center': '0.9927'}>,
#         <Axes: title={'center': '0.9937'}>,
#         <Axes: title={'center': '0.9939'}>,
#         <Axes: title={'center': '0.9941'}>,
#         <Axes: title={'center': '0.9942'}>],
#        [<Axes: title={'center': '0.9947'}>,
#         <Axes: title={'center': '0.9951'}>,
#         <Axes: title={'center': '0.9953'}>,
#         <Axes: title={'center': '0.9954'}>,
#         <Axes: title={'center': '0.9955'}>,
#         <Axes: title={'center': '0.9957'}>,
#         <Axes: title={'center': '0.9961'}>,
#         <Axes: title={'center': '0.9962'}>,
#         <Axes: title={'center': '0.9963'}>,
#         <Axes: title={'center': '0.9964'}>,
#         <Axes: title={'center': '0.9965'}>,
#         <Axes: title={'center': '0.9966'}>,
#         <Axes: title={'center': '0.9973'}>],
#        [<Axes: title={'center': '0.9975'}>,
#         <Axes: title={'center': '0.998'}>,
#         <Axes: title={'center': '0.9981'}>,
#         <Axes: title={'center': '0.9984'}>,
#         <Axes: title={'center': '0.9985'}>,
#         <Axes: title={'center': '0.9988'}>,
#         <Axes: title={'center': '0.9989'}>,
#         <Axes: title={'center': '0.999'}>,
#         <Axes: title={'center': '0.9991'}>,
#         <Axes: title={'center': '0.9992'}>,
#         <Axes: title={'center': '0.9994'}>,
#         <Axes: title={'center': '0.9995'}>,
#         <Axes: title={'center': '0.9997'}>],
#        [<Axes: title={'center': '0.9999'}>,
#         <Axes: title={'center': '1.0'}>,
#         <Axes: title={'center': '1.0002'}>,
#         <Axes: title={'center': '1.0004'}>,
#         <Axes: title={'center': '1.0005'}>,
#         <Axes: title={'center': '1.0009'}>,
#         <Axes: title={'center': '1.0011'}>,
#         <Axes: title={'center': '1.0013'}>,
#         <Axes: title={'center': '1.0014'}>,
#         <Axes: title={'center': '1.0015'}>,
#         <Axes: title={'center': '1.0017'}>,
#         <Axes: title={'center': '1.002'}>,
#         <Axes: title={'center': '1.0026'}>],
#        [<Axes: title={'center': '1.0027'}>,
#         <Axes: title={'center': '1.003'}>,
#         <Axes: title={'center': '1.0034'}>,
#         <Axes: title={'center': '1.0035'}>,
#         <Axes: title={'center': '1.0036'}>,
#         <Axes: title={'center': '1.0037'}>,
#         <Axes: title={'center': '1.0038'}>,
#         <Axes: title={'center': '1.004'}>,
#         <Axes: title={'center': '1.0043'}>,
#         <Axes: title={'center': '1.0044'}>,
#         <Axes: title={'center': '1.0045'}>,
#         <Axes: title={'center': '1.0046'}>,
#         <Axes: title={'center': '1.0048'}>],
#        [<Axes: title={'center': '1.0051'}>,
#         <Axes: title={'center': '1.0052'}>,
#         <Axes: title={'center': '1.0056'}>,
#         <Axes: title={'center': '1.0057'}>,
#         <Axes: title={'center': '1.0058'}>,
#         <Axes: title={'center': '1.0059'}>,
#         <Axes: title={'center': '1.0061'}>,
#         <Axes: title={'center': '1.0063'}>,
#         <Axes: title={'center': '1.0064'}>,
#         <Axes: title={'center': '1.0066'}>,
#         <Axes: title={'center': '1.0067'}>,
#         <Axes: title={'center': '1.0068'}>,
#         <Axes: title={'center': '1.0069'}>],
#        [<Axes: title={'center': '1.0071'}>,
#         <Axes: title={'center': '1.0073'}>,
#         <Axes: title={'center': '1.0074'}>,
#         <Axes: title={'center': '1.0075'}>,
#         <Axes: title={'center': '1.0076'}>,
#         <Axes: title={'center': '1.0078'}>,
#         <Axes: title={'center': '1.0079'}>,
#         <Axes: title={'center': '1.0081'}>,
#         <Axes: title={'center': '1.0082'}>,
#         <Axes: title={'center': '1.0084'}>,
#         <Axes: title={'center': '1.0089'}>,
#         <Axes: title={'center': '1.0091'}>,
#         <Axes: title={'center': '1.0096'}>],
#        [<Axes: title={'center': '1.0098'}>,
#         <Axes: title={'center': '1.0099'}>,
#         <Axes: title={'center': '1.01'}>,
#         <Axes: title={'center': '1.0103'}>,
#         <Axes: title={'center': '1.0105'}>,
#         <Axes: title={'center': '1.0106'}>,
#         <Axes: title={'center': '1.0107'}>,
#         <Axes: title={'center': '1.0108'}>,
#         <Axes: title={'center': '1.0109'}>,
#         <Axes: title={'center': '1.0114'}>,
#         <Axes: title={'center': '1.0115'}>,
#         <Axes: title={'center': '1.0119'}>,
#         <Axes: title={'center': '1.012'}>],
#        [<Axes: title={'center': '1.0123'}>,
#         <Axes: title={'center': '1.0124'}>,
#         <Axes: title={'center': '1.0125'}>,
#         <Axes: title={'center': '1.0128'}>,
#         <Axes: title={'center': '1.0129'}>,
#         <Axes: title={'center': '1.0131'}>,
#         <Axes: title={'center': '1.0132'}>,
#         <Axes: title={'center': '1.0134'}>,
#         <Axes: title={'center': '1.0138'}>,
#         <Axes: title={'center': '1.014'}>,
#         <Axes: title={'center': '1.0141'}>,
#         <Axes: title={'center': '1.0143'}>,
#         <Axes: title={'center': '1.0146'}>],
#        [<Axes: title={'center': '1.0147'}>,
#         <Axes: title={'center': '1.015'}>,
#         <Axes: title={'center': '1.0151'}>,
#         <Axes: title={'center': '1.0153'}>,
#         <Axes: title={'center': '1.0154'}>,
#         <Axes: title={'center': '1.0155'}>,
#         <Axes: title={'center': '1.0158'}>,
#         <Axes: title={'center': '1.016'}>,
#         <Axes: title={'center': '1.0162'}>,
#         <Axes: title={'center': '1.0164'}>,
#         <Axes: title={'center': '1.0165'}>,
#         <Axes: title={'center': '1.0171'}>,
#         <Axes: title={'center': '1.0176'}>],
#        [<Axes: title={'center': '1.0183'}>,
#         <Axes: title={'center': '1.0184'}>,
#         <Axes: title={'center': '1.0191'}>,
#         <Axes: title={'center': '1.0192'}>,
#         <Axes: title={'center': '1.0193'}>,
#         <Axes: title={'center': '1.0194'}>,
#         <Axes: title={'center': '1.0196'}>,
#         <Axes: title={'center': '1.0204'}>,
#         <Axes: title={'center': '1.0208'}>,
#         <Axes: title={'center': '1.021'}>,
#         <Axes: title={'center': '1.0217'}>,
#         <Axes: title={'center': '1.0218'}>,
#         <Axes: title={'center': '1.022'}>],
#        [<Axes: title={'center': '1.0221'}>,
#         <Axes: title={'center': '1.0224'}>,
#         <Axes: title={'center': '1.0227'}>,
#         <Axes: title={'center': '1.0231'}>,
#         <Axes: title={'center': '1.0232'}>,
#         <Axes: title={'center': '1.0234'}>,
#         <Axes: title={'center': '1.0236'}>,
#         <Axes: title={'center': '1.0238'}>,
#         <Axes: title={'center': '1.0239'}>,
#         <Axes: title={'center': '1.0241'}>,
#         <Axes: title={'center': '1.0242'}>,
#         <Axes: title={'center': '1.0247'}>,
#         <Axes: title={'center': '1.0248'}>],
#        [<Axes: title={'center': '1.025'}>,
#         <Axes: title={'center': '1.0257'}>,
#         <Axes: title={'center': '1.0259'}>,
#         <Axes: title={'center': '1.0261'}>,
#         <Axes: title={'center': '1.0263'}>,
#         <Axes: title={'center': '1.0265'}>,
#         <Axes: title={'center': '1.0267'}>,
#         <Axes: title={'center': '1.027'}>,
#         <Axes: title={'center': '1.0274'}>,
#         <Axes: title={'center': '1.0278'}>,
#         <Axes: title={'center': '1.028'}>,
#         <Axes: title={'center': '1.03'}>,
#         <Axes: title={'center': '1.0304'}>],
#        [<Axes: title={'center': '1.0312'}>,
#         <Axes: title={'center': '1.0314'}>,
#         <Axes: title={'center': '1.0315'}>,
#         <Axes: title={'center': '1.0316'}>,
#         <Axes: title={'center': '1.0319'}>,
#         <Axes: title={'center': '1.0325'}>,
#         <Axes: title={'center': '1.0359'}>,
#         <Axes: title={'center': '1.0376'}>,
#         <Axes: title={'center': '1.0378'}>,
#         <Axes: title={'center': '1.0404'}>,
#         <Axes: title={'center': '1.0691'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
mydata.hist(by='Growth Rate',column = 'Area (km²)')
# Out:
# array([[<Axes: title={'center': '0.912'}>,
#         <Axes: title={'center': '0.9816'}>,
#         <Axes: title={'center': '0.9831'}>,
#         <Axes: title={'center': '0.9849'}>,
#         <Axes: title={'center': '0.9869'}>,
#         <Axes: title={'center': '0.9876'}>,
#         <Axes: title={'center': '0.9886'}>,
#         <Axes: title={'center': '0.9897'}>,
#         <Axes: title={'center': '0.9927'}>,
#         <Axes: title={'center': '0.9937'}>,
#         <Axes: title={'center': '0.9939'}>,
#         <Axes: title={'center': '0.9941'}>,
#         <Axes: title={'center': '0.9942'}>],
#        [<Axes: title={'center': '0.9947'}>,
#         <Axes: title={'center': '0.9951'}>,
#         <Axes: title={'center': '0.9953'}>,
#         <Axes: title={'center': '0.9954'}>,
#         <Axes: title={'center': '0.9955'}>,
#         <Axes: title={'center': '0.9957'}>,
#         <Axes: title={'center': '0.9961'}>,
#         <Axes: title={'center': '0.9962'}>,
#         <Axes: title={'center': '0.9963'}>,
#         <Axes: title={'center': '0.9964'}>,
#         <Axes: title={'center': '0.9965'}>,
#         <Axes: title={'center': '0.9966'}>,
#         <Axes: title={'center': '0.9973'}>],
#        [<Axes: title={'center': '0.9975'}>,
#         <Axes: title={'center': '0.998'}>,
#         <Axes: title={'center': '0.9981'}>,
#         <Axes: title={'center': '0.9984'}>,
#         <Axes: title={'center': '0.9985'}>,
#         <Axes: title={'center': '0.9988'}>,
#         <Axes: title={'center': '0.9989'}>,
#         <Axes: title={'center': '0.999'}>,
#         <Axes: title={'center': '0.9991'}>,
#         <Axes: title={'center': '0.9992'}>,
#         <Axes: title={'center': '0.9994'}>,
#         <Axes: title={'center': '0.9995'}>,
#         <Axes: title={'center': '0.9997'}>],
#        [<Axes: title={'center': '0.9999'}>,
#         <Axes: title={'center': '1.0'}>,
#         <Axes: title={'center': '1.0002'}>,
#         <Axes: title={'center': '1.0004'}>,
#         <Axes: title={'center': '1.0005'}>,
#         <Axes: title={'center': '1.0009'}>,
#         <Axes: title={'center': '1.0011'}>,
#         <Axes: title={'center': '1.0013'}>,
#         <Axes: title={'center': '1.0014'}>,
#         <Axes: title={'center': '1.0015'}>,
#         <Axes: title={'center': '1.0017'}>,
#         <Axes: title={'center': '1.002'}>,
#         <Axes: title={'center': '1.0026'}>],
#        [<Axes: title={'center': '1.0027'}>,
#         <Axes: title={'center': '1.003'}>,
#         <Axes: title={'center': '1.0034'}>,
#         <Axes: title={'center': '1.0035'}>,
#         <Axes: title={'center': '1.0036'}>,
#         <Axes: title={'center': '1.0037'}>,
#         <Axes: title={'center': '1.0038'}>,
#         <Axes: title={'center': '1.004'}>,
#         <Axes: title={'center': '1.0043'}>,
#         <Axes: title={'center': '1.0044'}>,
#         <Axes: title={'center': '1.0045'}>,
#         <Axes: title={'center': '1.0046'}>,
#         <Axes: title={'center': '1.0048'}>],
#        [<Axes: title={'center': '1.0051'}>,
#         <Axes: title={'center': '1.0052'}>,
#         <Axes: title={'center': '1.0056'}>,
#         <Axes: title={'center': '1.0057'}>,
#         <Axes: title={'center': '1.0058'}>,
#         <Axes: title={'center': '1.0059'}>,
#         <Axes: title={'center': '1.0061'}>,
#         <Axes: title={'center': '1.0063'}>,
#         <Axes: title={'center': '1.0064'}>,
#         <Axes: title={'center': '1.0066'}>,
#         <Axes: title={'center': '1.0067'}>,
#         <Axes: title={'center': '1.0068'}>,
#         <Axes: title={'center': '1.0069'}>],
#        [<Axes: title={'center': '1.0071'}>,
#         <Axes: title={'center': '1.0073'}>,
#         <Axes: title={'center': '1.0074'}>,
#         <Axes: title={'center': '1.0075'}>,
#         <Axes: title={'center': '1.0076'}>,
#         <Axes: title={'center': '1.0078'}>,
#         <Axes: title={'center': '1.0079'}>,
#         <Axes: title={'center': '1.0081'}>,
#         <Axes: title={'center': '1.0082'}>,
#         <Axes: title={'center': '1.0084'}>,
#         <Axes: title={'center': '1.0089'}>,
#         <Axes: title={'center': '1.0091'}>,
#         <Axes: title={'center': '1.0096'}>],
#        [<Axes: title={'center': '1.0098'}>,
#         <Axes: title={'center': '1.0099'}>,
#         <Axes: title={'center': '1.01'}>,
#         <Axes: title={'center': '1.0103'}>,
#         <Axes: title={'center': '1.0105'}>,
#         <Axes: title={'center': '1.0106'}>,
#         <Axes: title={'center': '1.0107'}>,
#         <Axes: title={'center': '1.0108'}>,
#         <Axes: title={'center': '1.0109'}>,
#         <Axes: title={'center': '1.0114'}>,
#         <Axes: title={'center': '1.0115'}>,
#         <Axes: title={'center': '1.0119'}>,
#         <Axes: title={'center': '1.012'}>],
#        [<Axes: title={'center': '1.0123'}>,
#         <Axes: title={'center': '1.0124'}>,
#         <Axes: title={'center': '1.0125'}>,
#         <Axes: title={'center': '1.0128'}>,
#         <Axes: title={'center': '1.0129'}>,
#         <Axes: title={'center': '1.0131'}>,
#         <Axes: title={'center': '1.0132'}>,
#         <Axes: title={'center': '1.0134'}>,
#         <Axes: title={'center': '1.0138'}>,
#         <Axes: title={'center': '1.014'}>,
#         <Axes: title={'center': '1.0141'}>,
#         <Axes: title={'center': '1.0143'}>,
#         <Axes: title={'center': '1.0146'}>],
#        [<Axes: title={'center': '1.0147'}>,
#         <Axes: title={'center': '1.015'}>,
#         <Axes: title={'center': '1.0151'}>,
#         <Axes: title={'center': '1.0153'}>,
#         <Axes: title={'center': '1.0154'}>,
#         <Axes: title={'center': '1.0155'}>,
#         <Axes: title={'center': '1.0158'}>,
#         <Axes: title={'center': '1.016'}>,
#         <Axes: title={'center': '1.0162'}>,
#         <Axes: title={'center': '1.0164'}>,
#         <Axes: title={'center': '1.0165'}>,
#         <Axes: title={'center': '1.0171'}>,
#         <Axes: title={'center': '1.0176'}>],
#        [<Axes: title={'center': '1.0183'}>,
#         <Axes: title={'center': '1.0184'}>,
#         <Axes: title={'center': '1.0191'}>,
#         <Axes: title={'center': '1.0192'}>,
#         <Axes: title={'center': '1.0193'}>,
#         <Axes: title={'center': '1.0194'}>,
#         <Axes: title={'center': '1.0196'}>,
#         <Axes: title={'center': '1.0204'}>,
#         <Axes: title={'center': '1.0208'}>,
#         <Axes: title={'center': '1.021'}>,
#         <Axes: title={'center': '1.0217'}>,
#         <Axes: title={'center': '1.0218'}>,
#         <Axes: title={'center': '1.022'}>],
#        [<Axes: title={'center': '1.0221'}>,
#         <Axes: title={'center': '1.0224'}>,
#         <Axes: title={'center': '1.0227'}>,
#         <Axes: title={'center': '1.0231'}>,
#         <Axes: title={'center': '1.0232'}>,
#         <Axes: title={'center': '1.0234'}>,
#         <Axes: title={'center': '1.0236'}>,
#         <Axes: title={'center': '1.0238'}>,
#         <Axes: title={'center': '1.0239'}>,
#         <Axes: title={'center': '1.0241'}>,
#         <Axes: title={'center': '1.0242'}>,
#         <Axes: title={'center': '1.0247'}>,
#         <Axes: title={'center': '1.0248'}>],
#        [<Axes: title={'center': '1.025'}>,
#         <Axes: title={'center': '1.0257'}>,
#         <Axes: title={'center': '1.0259'}>,
#         <Axes: title={'center': '1.0261'}>,
#         <Axes: title={'center': '1.0263'}>,
#         <Axes: title={'center': '1.0265'}>,
#         <Axes: title={'center': '1.0267'}>,
#         <Axes: title={'center': '1.027'}>,
#         <Axes: title={'center': '1.0274'}>,
#         <Axes: title={'center': '1.0278'}>,
#         <Axes: title={'center': '1.028'}>,
#         <Axes: title={'center': '1.03'}>,
#         <Axes: title={'center': '1.0304'}>],
#        [<Axes: title={'center': '1.0312'}>,
#         <Axes: title={'center': '1.0314'}>,
#         <Axes: title={'center': '1.0315'}>,
#         <Axes: title={'center': '1.0316'}>,
#         <Axes: title={'center': '1.0319'}>,
#         <Axes: title={'center': '1.0325'}>,
#         <Axes: title={'center': '1.0359'}>,
#         <Axes: title={'center': '1.0376'}>,
#         <Axes: title={'center': '1.0378'}>,
#         <Axes: title={'center': '1.0404'}>,
#         <Axes: title={'center': '1.0691'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
mydata.hist(by='Growth Rate',column = 'Area (km²)')
# Out:
# array([[<Axes: title={'center': '0.912'}>,
#         <Axes: title={'center': '0.9816'}>,
#         <Axes: title={'center': '0.9831'}>,
#         <Axes: title={'center': '0.9849'}>,
#         <Axes: title={'center': '0.9869'}>,
#         <Axes: title={'center': '0.9876'}>,
#         <Axes: title={'center': '0.9886'}>,
#         <Axes: title={'center': '0.9897'}>,
#         <Axes: title={'center': '0.9927'}>,
#         <Axes: title={'center': '0.9937'}>,
#         <Axes: title={'center': '0.9939'}>,
#         <Axes: title={'center': '0.9941'}>,
#         <Axes: title={'center': '0.9942'}>],
#        [<Axes: title={'center': '0.9947'}>,
#         <Axes: title={'center': '0.9951'}>,
#         <Axes: title={'center': '0.9953'}>,
#         <Axes: title={'center': '0.9954'}>,
#         <Axes: title={'center': '0.9955'}>,
#         <Axes: title={'center': '0.9957'}>,
#         <Axes: title={'center': '0.9961'}>,
#         <Axes: title={'center': '0.9962'}>,
#         <Axes: title={'center': '0.9963'}>,
#         <Axes: title={'center': '0.9964'}>,
#         <Axes: title={'center': '0.9965'}>,
#         <Axes: title={'center': '0.9966'}>,
#         <Axes: title={'center': '0.9973'}>],
#        [<Axes: title={'center': '0.9975'}>,
#         <Axes: title={'center': '0.998'}>,
#         <Axes: title={'center': '0.9981'}>,
#         <Axes: title={'center': '0.9984'}>,
#         <Axes: title={'center': '0.9985'}>,
#         <Axes: title={'center': '0.9988'}>,
#         <Axes: title={'center': '0.9989'}>,
#         <Axes: title={'center': '0.999'}>,
#         <Axes: title={'center': '0.9991'}>,
#         <Axes: title={'center': '0.9992'}>,
#         <Axes: title={'center': '0.9994'}>,
#         <Axes: title={'center': '0.9995'}>,
#         <Axes: title={'center': '0.9997'}>],
#        [<Axes: title={'center': '0.9999'}>,
#         <Axes: title={'center': '1.0'}>,
#         <Axes: title={'center': '1.0002'}>,
#         <Axes: title={'center': '1.0004'}>,
#         <Axes: title={'center': '1.0005'}>,
#         <Axes: title={'center': '1.0009'}>,
#         <Axes: title={'center': '1.0011'}>,
#         <Axes: title={'center': '1.0013'}>,
#         <Axes: title={'center': '1.0014'}>,
#         <Axes: title={'center': '1.0015'}>,
#         <Axes: title={'center': '1.0017'}>,
#         <Axes: title={'center': '1.002'}>,
#         <Axes: title={'center': '1.0026'}>],
#        [<Axes: title={'center': '1.0027'}>,
#         <Axes: title={'center': '1.003'}>,
#         <Axes: title={'center': '1.0034'}>,
#         <Axes: title={'center': '1.0035'}>,
#         <Axes: title={'center': '1.0036'}>,
#         <Axes: title={'center': '1.0037'}>,
#         <Axes: title={'center': '1.0038'}>,
#         <Axes: title={'center': '1.004'}>,
#         <Axes: title={'center': '1.0043'}>,
#         <Axes: title={'center': '1.0044'}>,
#         <Axes: title={'center': '1.0045'}>,
#         <Axes: title={'center': '1.0046'}>,
#         <Axes: title={'center': '1.0048'}>],
#        [<Axes: title={'center': '1.0051'}>,
#         <Axes: title={'center': '1.0052'}>,
#         <Axes: title={'center': '1.0056'}>,
#         <Axes: title={'center': '1.0057'}>,
#         <Axes: title={'center': '1.0058'}>,
#         <Axes: title={'center': '1.0059'}>,
#         <Axes: title={'center': '1.0061'}>,
#         <Axes: title={'center': '1.0063'}>,
#         <Axes: title={'center': '1.0064'}>,
#         <Axes: title={'center': '1.0066'}>,
#         <Axes: title={'center': '1.0067'}>,
#         <Axes: title={'center': '1.0068'}>,
#         <Axes: title={'center': '1.0069'}>],
#        [<Axes: title={'center': '1.0071'}>,
#         <Axes: title={'center': '1.0073'}>,
#         <Axes: title={'center': '1.0074'}>,
#         <Axes: title={'center': '1.0075'}>,
#         <Axes: title={'center': '1.0076'}>,
#         <Axes: title={'center': '1.0078'}>,
#         <Axes: title={'center': '1.0079'}>,
#         <Axes: title={'center': '1.0081'}>,
#         <Axes: title={'center': '1.0082'}>,
#         <Axes: title={'center': '1.0084'}>,
#         <Axes: title={'center': '1.0089'}>,
#         <Axes: title={'center': '1.0091'}>,
#         <Axes: title={'center': '1.0096'}>],
#        [<Axes: title={'center': '1.0098'}>,
#         <Axes: title={'center': '1.0099'}>,
#         <Axes: title={'center': '1.01'}>,
#         <Axes: title={'center': '1.0103'}>,
#         <Axes: title={'center': '1.0105'}>,
#         <Axes: title={'center': '1.0106'}>,
#         <Axes: title={'center': '1.0107'}>,
#         <Axes: title={'center': '1.0108'}>,
#         <Axes: title={'center': '1.0109'}>,
#         <Axes: title={'center': '1.0114'}>,
#         <Axes: title={'center': '1.0115'}>,
#         <Axes: title={'center': '1.0119'}>,
#         <Axes: title={'center': '1.012'}>],
#        [<Axes: title={'center': '1.0123'}>,
#         <Axes: title={'center': '1.0124'}>,
#         <Axes: title={'center': '1.0125'}>,
#         <Axes: title={'center': '1.0128'}>,
#         <Axes: title={'center': '1.0129'}>,
#         <Axes: title={'center': '1.0131'}>,
#         <Axes: title={'center': '1.0132'}>,
#         <Axes: title={'center': '1.0134'}>,
#         <Axes: title={'center': '1.0138'}>,
#         <Axes: title={'center': '1.014'}>,
#         <Axes: title={'center': '1.0141'}>,
#         <Axes: title={'center': '1.0143'}>,
#         <Axes: title={'center': '1.0146'}>],
#        [<Axes: title={'center': '1.0147'}>,
#         <Axes: title={'center': '1.015'}>,
#         <Axes: title={'center': '1.0151'}>,
#         <Axes: title={'center': '1.0153'}>,
#         <Axes: title={'center': '1.0154'}>,
#         <Axes: title={'center': '1.0155'}>,
#         <Axes: title={'center': '1.0158'}>,
#         <Axes: title={'center': '1.016'}>,
#         <Axes: title={'center': '1.0162'}>,
#         <Axes: title={'center': '1.0164'}>,
#         <Axes: title={'center': '1.0165'}>,
#         <Axes: title={'center': '1.0171'}>,
#         <Axes: title={'center': '1.0176'}>],
#        [<Axes: title={'center': '1.0183'}>,
#         <Axes: title={'center': '1.0184'}>,
#         <Axes: title={'center': '1.0191'}>,
#         <Axes: title={'center': '1.0192'}>,
#         <Axes: title={'center': '1.0193'}>,
#         <Axes: title={'center': '1.0194'}>,
#         <Axes: title={'center': '1.0196'}>,
#         <Axes: title={'center': '1.0204'}>,
#         <Axes: title={'center': '1.0208'}>,
#         <Axes: title={'center': '1.021'}>,
#         <Axes: title={'center': '1.0217'}>,
#         <Axes: title={'center': '1.0218'}>,
#         <Axes: title={'center': '1.022'}>],
#        [<Axes: title={'center': '1.0221'}>,
#         <Axes: title={'center': '1.0224'}>,
#         <Axes: title={'center': '1.0227'}>,
#         <Axes: title={'center': '1.0231'}>,
#         <Axes: title={'center': '1.0232'}>,
#         <Axes: title={'center': '1.0234'}>,
#         <Axes: title={'center': '1.0236'}>,
#         <Axes: title={'center': '1.0238'}>,
#         <Axes: title={'center': '1.0239'}>,
#         <Axes: title={'center': '1.0241'}>,
#         <Axes: title={'center': '1.0242'}>,
#         <Axes: title={'center': '1.0247'}>,
#         <Axes: title={'center': '1.0248'}>],
#        [<Axes: title={'center': '1.025'}>,
#         <Axes: title={'center': '1.0257'}>,
#         <Axes: title={'center': '1.0259'}>,
#         <Axes: title={'center': '1.0261'}>,
#         <Axes: title={'center': '1.0263'}>,
#         <Axes: title={'center': '1.0265'}>,
#         <Axes: title={'center': '1.0267'}>,
#         <Axes: title={'center': '1.027'}>,
#         <Axes: title={'center': '1.0274'}>,
#         <Axes: title={'center': '1.0278'}>,
#         <Axes: title={'center': '1.028'}>,
#         <Axes: title={'center': '1.03'}>,
#         <Axes: title={'center': '1.0304'}>],
#        [<Axes: title={'center': '1.0312'}>,
#         <Axes: title={'center': '1.0314'}>,
#         <Axes: title={'center': '1.0315'}>,
#         <Axes: title={'center': '1.0316'}>,
#         <Axes: title={'center': '1.0319'}>,
#         <Axes: title={'center': '1.0325'}>,
#         <Axes: title={'center': '1.0359'}>,
#         <Axes: title={'center': '1.0376'}>,
#         <Axes: title={'center': '1.0378'}>,
#         <Axes: title={'center': '1.0404'}>,
#         <Axes: title={'center': '1.0691'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
mydata.hist(by='Growth Rate',column = 'Area (km²)', figsize=(20,30))
# Out:
# array([[<Axes: title={'center': '0.912'}>,
#         <Axes: title={'center': '0.9816'}>,
#         <Axes: title={'center': '0.9831'}>,
#         <Axes: title={'center': '0.9849'}>,
#         <Axes: title={'center': '0.9869'}>,
#         <Axes: title={'center': '0.9876'}>,
#         <Axes: title={'center': '0.9886'}>,
#         <Axes: title={'center': '0.9897'}>,
#         <Axes: title={'center': '0.9927'}>,
#         <Axes: title={'center': '0.9937'}>,
#         <Axes: title={'center': '0.9939'}>,
#         <Axes: title={'center': '0.9941'}>,
#         <Axes: title={'center': '0.9942'}>],
#        [<Axes: title={'center': '0.9947'}>,
#         <Axes: title={'center': '0.9951'}>,
#         <Axes: title={'center': '0.9953'}>,
#         <Axes: title={'center': '0.9954'}>,
#         <Axes: title={'center': '0.9955'}>,
#         <Axes: title={'center': '0.9957'}>,
#         <Axes: title={'center': '0.9961'}>,
#         <Axes: title={'center': '0.9962'}>,
#         <Axes: title={'center': '0.9963'}>,
#         <Axes: title={'center': '0.9964'}>,
#         <Axes: title={'center': '0.9965'}>,
#         <Axes: title={'center': '0.9966'}>,
#         <Axes: title={'center': '0.9973'}>],
#        [<Axes: title={'center': '0.9975'}>,
#         <Axes: title={'center': '0.998'}>,
#         <Axes: title={'center': '0.9981'}>,
#         <Axes: title={'center': '0.9984'}>,
#         <Axes: title={'center': '0.9985'}>,
#         <Axes: title={'center': '0.9988'}>,
#         <Axes: title={'center': '0.9989'}>,
#         <Axes: title={'center': '0.999'}>,
#         <Axes: title={'center': '0.9991'}>,
#         <Axes: title={'center': '0.9992'}>,
#         <Axes: title={'center': '0.9994'}>,
#         <Axes: title={'center': '0.9995'}>,
#         <Axes: title={'center': '0.9997'}>],
#        [<Axes: title={'center': '0.9999'}>,
#         <Axes: title={'center': '1.0'}>,
#         <Axes: title={'center': '1.0002'}>,
#         <Axes: title={'center': '1.0004'}>,
#         <Axes: title={'center': '1.0005'}>,
#         <Axes: title={'center': '1.0009'}>,
#         <Axes: title={'center': '1.0011'}>,
#         <Axes: title={'center': '1.0013'}>,
#         <Axes: title={'center': '1.0014'}>,
#         <Axes: title={'center': '1.0015'}>,
#         <Axes: title={'center': '1.0017'}>,
#         <Axes: title={'center': '1.002'}>,
#         <Axes: title={'center': '1.0026'}>],
#        [<Axes: title={'center': '1.0027'}>,
#         <Axes: title={'center': '1.003'}>,
#         <Axes: title={'center': '1.0034'}>,
#         <Axes: title={'center': '1.0035'}>,
#         <Axes: title={'center': '1.0036'}>,
#         <Axes: title={'center': '1.0037'}>,
#         <Axes: title={'center': '1.0038'}>,
#         <Axes: title={'center': '1.004'}>,
#         <Axes: title={'center': '1.0043'}>,
#         <Axes: title={'center': '1.0044'}>,
#         <Axes: title={'center': '1.0045'}>,
#         <Axes: title={'center': '1.0046'}>,
#         <Axes: title={'center': '1.0048'}>],
#        [<Axes: title={'center': '1.0051'}>,
#         <Axes: title={'center': '1.0052'}>,
#         <Axes: title={'center': '1.0056'}>,
#         <Axes: title={'center': '1.0057'}>,
#         <Axes: title={'center': '1.0058'}>,
#         <Axes: title={'center': '1.0059'}>,
#         <Axes: title={'center': '1.0061'}>,
#         <Axes: title={'center': '1.0063'}>,
#         <Axes: title={'center': '1.0064'}>,
#         <Axes: title={'center': '1.0066'}>,
#         <Axes: title={'center': '1.0067'}>,
#         <Axes: title={'center': '1.0068'}>,
#         <Axes: title={'center': '1.0069'}>],
#        [<Axes: title={'center': '1.0071'}>,
#         <Axes: title={'center': '1.0073'}>,
#         <Axes: title={'center': '1.0074'}>,
#         <Axes: title={'center': '1.0075'}>,
#         <Axes: title={'center': '1.0076'}>,
#         <Axes: title={'center': '1.0078'}>,
#         <Axes: title={'center': '1.0079'}>,
#         <Axes: title={'center': '1.0081'}>,
#         <Axes: title={'center': '1.0082'}>,
#         <Axes: title={'center': '1.0084'}>,
#         <Axes: title={'center': '1.0089'}>,
#         <Axes: title={'center': '1.0091'}>,
#         <Axes: title={'center': '1.0096'}>],
#        [<Axes: title={'center': '1.0098'}>,
#         <Axes: title={'center': '1.0099'}>,
#         <Axes: title={'center': '1.01'}>,
#         <Axes: title={'center': '1.0103'}>,
#         <Axes: title={'center': '1.0105'}>,
#         <Axes: title={'center': '1.0106'}>,
#         <Axes: title={'center': '1.0107'}>,
#         <Axes: title={'center': '1.0108'}>,
#         <Axes: title={'center': '1.0109'}>,
#         <Axes: title={'center': '1.0114'}>,
#         <Axes: title={'center': '1.0115'}>,
#         <Axes: title={'center': '1.0119'}>,
#         <Axes: title={'center': '1.012'}>],
#        [<Axes: title={'center': '1.0123'}>,
#         <Axes: title={'center': '1.0124'}>,
#         <Axes: title={'center': '1.0125'}>,
#         <Axes: title={'center': '1.0128'}>,
#         <Axes: title={'center': '1.0129'}>,
#         <Axes: title={'center': '1.0131'}>,
#         <Axes: title={'center': '1.0132'}>,
#         <Axes: title={'center': '1.0134'}>,
#         <Axes: title={'center': '1.0138'}>,
#         <Axes: title={'center': '1.014'}>,
#         <Axes: title={'center': '1.0141'}>,
#         <Axes: title={'center': '1.0143'}>,
#         <Axes: title={'center': '1.0146'}>],
#        [<Axes: title={'center': '1.0147'}>,
#         <Axes: title={'center': '1.015'}>,
#         <Axes: title={'center': '1.0151'}>,
#         <Axes: title={'center': '1.0153'}>,
#         <Axes: title={'center': '1.0154'}>,
#         <Axes: title={'center': '1.0155'}>,
#         <Axes: title={'center': '1.0158'}>,
#         <Axes: title={'center': '1.016'}>,
#         <Axes: title={'center': '1.0162'}>,
#         <Axes: title={'center': '1.0164'}>,
#         <Axes: title={'center': '1.0165'}>,
#         <Axes: title={'center': '1.0171'}>,
#         <Axes: title={'center': '1.0176'}>],
#        [<Axes: title={'center': '1.0183'}>,
#         <Axes: title={'center': '1.0184'}>,
#         <Axes: title={'center': '1.0191'}>,
#         <Axes: title={'center': '1.0192'}>,
#         <Axes: title={'center': '1.0193'}>,
#         <Axes: title={'center': '1.0194'}>,
#         <Axes: title={'center': '1.0196'}>,
#         <Axes: title={'center': '1.0204'}>,
#         <Axes: title={'center': '1.0208'}>,
#         <Axes: title={'center': '1.021'}>,
#         <Axes: title={'center': '1.0217'}>,
#         <Axes: title={'center': '1.0218'}>,
#         <Axes: title={'center': '1.022'}>],
#        [<Axes: title={'center': '1.0221'}>,
#         <Axes: title={'center': '1.0224'}>,
#         <Axes: title={'center': '1.0227'}>,
#         <Axes: title={'center': '1.0231'}>,
#         <Axes: title={'center': '1.0232'}>,
#         <Axes: title={'center': '1.0234'}>,
#         <Axes: title={'center': '1.0236'}>,
#         <Axes: title={'center': '1.0238'}>,
#         <Axes: title={'center': '1.0239'}>,
#         <Axes: title={'center': '1.0241'}>,
#         <Axes: title={'center': '1.0242'}>,
#         <Axes: title={'center': '1.0247'}>,
#         <Axes: title={'center': '1.0248'}>],
#        [<Axes: title={'center': '1.025'}>,
#         <Axes: title={'center': '1.0257'}>,
#         <Axes: title={'center': '1.0259'}>,
#         <Axes: title={'center': '1.0261'}>,
#         <Axes: title={'center': '1.0263'}>,
#         <Axes: title={'center': '1.0265'}>,
#         <Axes: title={'center': '1.0267'}>,
#         <Axes: title={'center': '1.027'}>,
#         <Axes: title={'center': '1.0274'}>,
#         <Axes: title={'center': '1.0278'}>,
#         <Axes: title={'center': '1.028'}>,
#         <Axes: title={'center': '1.03'}>,
#         <Axes: title={'center': '1.0304'}>],
#        [<Axes: title={'center': '1.0312'}>,
#         <Axes: title={'center': '1.0314'}>,
#         <Axes: title={'center': '1.0315'}>,
#         <Axes: title={'center': '1.0316'}>,
#         <Axes: title={'center': '1.0319'}>,
#         <Axes: title={'center': '1.0325'}>,
#         <Axes: title={'center': '1.0359'}>,
#         <Axes: title={'center': '1.0376'}>,
#         <Axes: title={'center': '1.0378'}>,
#         <Axes: title={'center': '1.0404'}>,
#         <Axes: title={'center': '1.0691'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
sns.pairplot(mydata)

# %% [markdown]
# <style>
#   ul {
#     background-color: black;
#   }
#
# <div>
# <span style="color: pink;">
# <h2> Project: concider specification of your dataset </h2>
#     <h3>
#     <ul>
#   <li>Apply all above codes</li>
#   <li>Allways be creative to find interested information</li>
#   <li> Arrange and clean up your GitHub</li>
#     </ul>
#     </h3>
# </div>
#     </style>

# %% [markdown]
# <ul style="background-color: gray;">
#     <div style="color: yalow;font-size: 46px>
#   <li>analyze</li>
#   <li>create</li>
#                 </div>
# </ul>

# %% [markdown]
# <div style="background-color: lightgreen; padding: 10px; text-align: center;">
#   <h2 style="color: green;">Project: Consider the Features of Your Dataset</h2>
#   <ol style="background-color: black; color: gold; font-size: 22px; line-height: 1.5; margin-left: 10px;text-align:left">
#     <li>Apply all codes</li>
#     <li>Always be creative and find interesting information</li>
#     <li>Arrange and clean up your GitHub</li>
#     <li>Take the chance and strengthen the spirit of teamwork</li>
#   </ol>
# </div>

# %% [markdown]
# <center>
# <span style="color: blue; font-size: 46px; font-weight: bold; text-decoration: underline;">
# <h1> Lab Work </h1>
# </center>

# %% [markdown]
# <div>
# <span style="color: yellow; font-size: 46px;>
#  <h2>LabWork 1: </h2>
# </div>
# Calculate qty of products for usage 4

# %% [markdown]
# <center>
# <span style="color: green; font-size: 16px;">
# <h1> Lab Work 1: </h1>
# </center>
# Create a cross-tabulation table between the "Product" column and a single value of the "Usage"  column of value 4 in the mydata DataFrame.

# %% [markdown]
# <center>
# <span style="color: green; font-size: 16px;">
# <h1> Lab Work 2: </h1>
# </center>
# Use pivot_table function from the Pandas library to create a pivot table from the mydata DataFrame. The resulting table should have the following features:
#
# 1. The rows of the table will be grouped by the "Product" and "MaritalStatus" columns.
# 2. The columns of the table will be grouped by the "Gender" column.
# 3. The values in the table will be the count of occurrences for each combination of row and column.

# %% [markdown]
# <center>
# <span style="color: green; font-size: 16px;">
# <h1> Lab Work 3: </h1>
# </center>
# Use the hist function from the Pandas library to create a histogram of the "Usage" column in the mydata DataFrame, grouped by the "Gender" column.

# %% [markdown]
# <div>
#     <span style="color: green;">
#     Below cell contains the code of LabWork 1 in white;
# </div>

# %% [markdown]
# <div>
# <span style="color: white; font-size: 16px;">
#
#
# # LabWork 1
# pd.crosstab(mydata['Product'],mydata['Usage'][4] )
# </div>

# %%
# Out:
# col_0     4
# Product
# TM195    80
# TM498    60
# TM798    40

# %% [markdown]
# <div>
#     <span style="color: green;">
#     Below cell contains the code of LabWork 2 in white;
# </div>

# %% [markdown]
# <div>
# <span style="color: white; font-size: 16px;">
#
#
# # LabWork 2
# pd.pivot_table(mydata, index=['Product', 'MaritalStatus'],
#                      columns=[ 'Gender'], aggfunc=len)
#                      </div>

# %%
# Out:
#                          Age      Education      Fitness      Income       \
# Gender                Female Male    Female Male  Female Male Female Male
# Product MaritalStatus
# TM195   Partnered         27   21        27   21      27   21     27   21
#         Single            13   19        13   19      13   19     13   19
# TM498   Partnered         15   21        15   21      15   21     15   21
#         Single            14   10        14   10      14   10     14   10
# TM798   Partnered          4   19         4   19       4   19      4   19
#         Single             3   14         3   14       3   14      3   14
#
#                        Miles       Usage
# Gender                Female Male Female Male
# Product MaritalStatus
# TM195   Partnered         27   21     27   21
#         Single            13   19     13   19
# TM498   Partnered         15   21     15   21
#         Single            14   10     14   10
# TM798   Partnered          4   19      4   19
#         Single             3   14      3   14

# %% [markdown]
# <div>
#     <span style="color: green;">
#     Below cell contains the code of LabWork 3 in white;
# </div>

# %% [markdown]
# <div>
# <span style="color: white; font-size: 16px;">
#
#
# # LabWork 3
# mydata.hist(by='Gender',column = 'Usage')
#     </div>

# %%
# Out:
# array([<AxesSubplot:title={'center':'Female'}>,
#        <AxesSubplot:title={'center':'Male'}>], dtype=object)
